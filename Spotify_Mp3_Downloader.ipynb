# %%
#@markdown #**Download file .mp3 Spotify on Google Drive**<br><br>

import os

# Instal spotdl package dengan menggunakan flag --no-deps untuk menghindari konflik dependensi
# !pip install spotdl --no-deps

# Install requests package dengan versi yang diperlukan
# !pip install requests==2.27.1

# Pindah jalur kerja ke folder tujuan di Google Drive
tujuan_folder = "/content/drive/MyDrive/Music"
os.makedirs(tujuan_folder, exist_ok=True)
os.chdir(tujuan_folder)

# Masukkan link Spotify untuk mengunduh lagu
link_spotify1 = "https://open.spotify.com/track/05Jv77XQY22tgNnLOQqEc5?si=23G8raFfTSStuUaARAhyYw&utm_source=copy-link"  #@param {'type': 'string'}
link_spotify2 = ""  #@param {'type': 'string'}
link_spotify3 = ""  #@param {'type': 'string'}
link_spotify4 = ""  #@param {'type': 'string'}

# Mulai unduhan menggunakan spotDL
links = [link for link in [link_spotify1, link_spotify2, link_spotify3, link_spotify4] if link]
for link in links:
    if link:
        # !spotdl {link} --output-format "{tujuan_folder}/%(title)s.%(ext)s" --bitrate 320

# %%
import os

# Instal spotdl package dengan menggunakan flag --no-deps untuk menghindari konflik dependensi
# !pip install spotdl --no-deps

# Install requests package dengan versi yang diperlukan
# !pip install requests==2.27.1

# Pindah jalur kerja ke folder tujuan di Google Drive
tujuan_folder = "/content/drive/MyDrive/Music"
os.makedirs(tujuan_folder, exist_ok=True)
os.chdir(tujuan_folder)

# Masukkan link Spotify untuk mengunduh lagu
link_spotify1 = "https://open.spotify.com/track/05Jv77XQY22tgNnLOQqEc5?si=23G8raFfTSStuUaARAhyYw&utm_source=copy-link"  #@param {'type': 'string'}
link_spotify2 = ""  #@param {'type': 'string'}
link_spotify3 = ""  #@param {'type': 'string'}
link_spotify4 = ""  #@param {'type': 'string'}

# Mulai unduhan menggunakan spotDL dengan bitrate 320 kbps
links = [link for link in [link_spotify1, link_spotify2, link_spotify3, link_spotify4] if link]
for link in links:
    if link:
        # !spotdl {link} --output-format "{tujuan_folder}/%(title)s.%(ext)s" --output-quality 320
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# /bin/bash: --output-format: command not found
# Traceback (most recent call last):
#   File "/usr/local/bin/spotdl", line 5, in <module>
#     from spotdl import console_entry_point
#   File "/usr/local/lib/python3.10/dist-packages/spotdl/__init__.py", line 13, in <module>
#     from spotdl.console import console_entry_point
#   File "/usr/local/lib/python3.10/dist-packages/spotdl/console/__init__.py", line 5, in <module>
#     from spotdl.console.entry_point import console_entry_point
#   File "/usr/local/lib/python3.10/dist-packages/spotdl/console/entry_point.py", line 9, in <module>
#     from spotdl.console.download import download
#   File "/usr/local/lib/python3.10/dist-packages/spotdl/console/download.py", line 7, in <module>
#     from spotdl.download.downloader import Downloader
# ...
